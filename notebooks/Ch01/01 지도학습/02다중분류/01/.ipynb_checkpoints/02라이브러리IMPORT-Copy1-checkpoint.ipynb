# %%
# 문제정의
## 고객별 신용등급 분류
## 1 - BAD, 2 - STANDARD, 3 - GOOD
## 타깃(라벨, y값) : Credit_Score

# %%
# 판다스 라이브러리
import pandas as pd

# 데이터 불러오기
train = pd.read.csv("./train.csv")
test = pd.read.csv("./test.csv")
